# %%
#Importing Packages 

import qiskit 
from qiskit import Aer, QuantumCircuit, execute
from qiskit.tools.visualization import plot_histogram
from qiskit import IBMQ
from qiskit import ClassicalRegister, QuantumRegister
import numpy as np
import matplotlib.pyplot
from matplotlib.pyplot import *
legend1=['W=I','W=X','W=Y','W=Z']
legend2=['ibmq_santiago', 'ibmq_vigo',  'ibmq_valencia',  'ibmq_ourense', 'ibmq_5_yorktown']

from matplotlib.lines import Line2D
#colors1= ['black','dimgrey','grey','darkgrey']
colors1= ['blue','orange','green', 'red']
#colors2= ['black','dimgrey','grey', 'darkgrey', 'silver']
colors2= ['blue','orange','green', 'red','purple']

Legend_Lines1 = [Line2D([0], [0], color=colors1[0], lw=4),
                Line2D([0], [0], color=colors1[1], lw=4),
                Line2D([0], [0], color=colors1[2], lw=4),
                Line2D([0], [0], color=colors1[3], lw=4)]
Legend_Lines2 = [Line2D([0], [0], color=colors2[0], lw=4),
                Line2D([0], [0], color=colors2[1], lw=4),
                Line2D([0], [0], color=colors2[2], lw=4),
                Line2D([0], [0], color=colors2[3], lw=4),
                Line2D([0], [0], color=colors2[4], lw=4)]

# %%
#XYZ Channel
#ibmq_burlington
#3Qubit Circuit

#Initial State 000
xyz3_0bun={'*00': 688, '*01': 63, '*10': 183, '*11': 90}   
xyz3_0bux={'*00': 572, '*01': 144, '*10': 152, '*11': 156}   
xyz3_0buy={'*00': 694, '*01': 82, '*10': 158, '*11': 90}   
xyz3_0buz={'*00': 659, '*01': 115, '*10': 98, '*11': 152}   

xyz3_0bu=plot_histogram([xyz3_0bun,xyz3_0bux,xyz3_0buy,xyz3_0buz], color=colors1, title='3-Qubit QECC with a classical protection (ancilla) qubit',figsize=(20,15))
yax_0bu3 = xyz3_0bu.axes[0]
yax_0bu3.set_ylim(0,1)
ax_0bu3 = xyz3_0bu.gca()
xyz3_0bu.legend(Legend_Lines1, legend1, bbox_to_anchor=(0.95, 0.95), bbox_transform=ax_0bu3.transAxes)
xyz3_0bu.savefig('XYZ_3q_pure.png')

#Initial State *00
xyz3_abun={'*00': 733, '*01': 70, '*10': 149, '*11': 72}   
xyz3_abux={'*00': 627, '*01': 94, '*10': 196, '*11': 107}   
xyz3_abuy={'*00': 667, '*01': 114, '*10': 110, '*11': 133}   
xyz3_abuz={'*00': 676, '*01': 90, '*10': 106, '*11': 152}   

xyz3_abu=plot_histogram([xyz3_abun,xyz3_abux,xyz3_abuy,xyz3_abuz], color=colors1, title='3-Qubit QECC with a nonclassical protection (ancilla) qubits',figsize=(20,15))
yax_abu3 = xyz3_abu.axes[0]
yax_abu3.set_ylim(0,1)
ax_abu3 = xyz3_abu.gca()
xyz3_abu.legend(Legend_Lines1, legend1, bbox_to_anchor=(0.95, 0.95), bbox_transform=ax_abu3.transAxes)
xyz3_abu.savefig('XYZ_3q_arb.png')

# %%
#XYZ Channel
#ibmq_burlington
#4Qubit Circuit

#Initial State 0000
xyz4_0bun={'**00': 661, '**01': 131, '**10': 154, '**11': 78}   
xyz4_0bux={'**00': 559, '**01': 108, '**10': 250, '**11': 107}   
xyz4_0buy={'**00': 623, '**01': 80, '**10': 246, '**11': 75}   
xyz4_0buz={'**00': 686, '**01': 61, '**10': 241, '**11': 36}   

xyz4_0bu=plot_histogram([xyz4_0bun,xyz4_0bux,xyz4_0buy,xyz4_0buz], color=colors1, title='4-Qubit QECC with a classical protection (ancilla) qubit',figsize=(20,15))
yax_0bu4 = xyz4_0bu.axes[0]
yax_0bu4.set_ylim(0,1)
ax_0bu4 = xyz4_0bu.gca()
xyz4_0bu.legend(Legend_Lines1, legend1, bbox_to_anchor=(0.95, 0.95), bbox_transform=ax_0bu4.transAxes)
xyz4_0bu.savefig('XYZ_4q_pure.png')


#Initial State **00
xyz4_abun={'**00': 602, '**01': 98, '**10': 229, '**11': 95}   
xyz4_abux={'**00': 645, '**01': 107, '**10': 174, '**11': 98}   
xyz4_abuy={'**00': 697, '**01': 83, '**10': 162, '**11': 82}   
xyz4_abuz={'**00': 646, '**01': 84, '**10': 161, '**11': 133}   


xyz4_abu=plot_histogram([xyz4_abun,xyz4_abux,xyz4_abuy,xyz4_abuz], color=colors1, title='4-Qubit QECC with a nonclassical protection (ancilla) qubits',figsize=(20,15))
yax_abu4 = xyz4_abu.axes[0]
yax_abu4.set_ylim(0,1)
ax_abu4 = xyz4_abu.gca()
xyz4_abu.legend(Legend_Lines1, legend1, bbox_to_anchor=(0.95, 0.95), bbox_transform=ax_abu4.transAxes)
xyz4_abu.savefig('XYZ_4q_arb.png')

# %%
#XYZ Channel
#4Qubit Circuit
#Initial State 0100

#ibmq_santiago
xyz4_1san={'0000':  55, '0001':  0, '0010':  0, '0011':  0, '0100': 1922, '0101': 33, '0110':  9, '0111':  1, '1000':   1, '1001':  0, '1010':  0, '1011':  0, '1100':  27, '1101':  0, '1110':  0, '1111':  0}  
xyz4_1sax={'0000': 121, '0001':  4, '0010': 22, '0011': 13, '0100':  778, '0101': 34, '0110': 33, '0111': 14, '1000': 779, '1001': 37, '1010': 45, '1011':  30, '1100': 97, '1101': 11, '1110': 19, '1111': 11} 
xyz4_1say={'0000': 160, '0001': 15, '0010': 31, '0011': 21, '0100':  591, '0101': 16, '0110': 53, '0111': 12, '1000': 918, '1001': 32, '1010': 47, '1011':  9, '1100':  87, '1101': 14, '1110': 26, '1111': 16}   
xyz4_1saz={'0000': 127, '0001': 14, '0010': 34, '0011': 14, '0100':  903, '0101': 24, '0110': 69, '0111': 16, '1000': 637, '1001': 15, '1010': 58, '1011':  7, '1100':  84, '1101': 12, '1110': 31, '1111': 13} 

xyz4_1sa=plot_histogram([xyz4_1san,xyz4_1sax,xyz4_1say,xyz4_1saz], color=colors1, title='4-Qubit QECC on ibmq_santiago using initial state 0100',figsize=(60,20))
yax_1sa4 = xyz4_1sa.axes[0]
yax_1sa4.set_ylim(0,1)
ax_1sa4 = xyz4_1sa.gca()
xyz4_1sa.legend(Legend_Lines1, legend1, bbox_to_anchor=(0.95, 0.95), bbox_transform=ax_1sa4.transAxes)
xyz4_1sa.savefig('XYZ_4q_0100_Santiago.png')


#Athens
xyz5_0bu.savefig('XYZ_5q_pure.png')


#Initial State *0000
xyz5_abun={'*0000': 406, '*0001': 17, '*0010': 72, '*0011': 21, '*0100':  86, '*0101': 10, '*0110': 51, '*0111': 14, '*1000': 162, '*1001': 13, '*1010': 36, '*1011':  8, '*1100': 80, '*1101':  6, '*1110': 30, '*1111':  12}   
xyz5_abux={'*0000': 449, '*0001': 23, '*0010': 53, '*0011':  9, '*0100': 106, '*0101': 11, '*0110': 42, '*0111': 21, '*1000': 104, '*1001':  9, '*1010': 17, '*1011': 11, '*1100': 75, '*1101': 17, '*1110': 40, '*1111':  37}   
xyz5_abuy={'*0000': 460, '*0001': 20, '*0010': 43, '*0011': 12, '*0100': 109, '*0101': 14, '*0110': 24, '*0111': 13, '*1000': 134, '*1001': 11, '*1010': 15, '*1011': 18, '*1100': 65, '*1101': 26, '*1110': 27, '*1111':  33}   
xyz5_abuz={'*0000': 287, '*0001': 28, '*0010': 76, '*0011': 15, '*0100': 108, '*0101': 18, '*0110': 51, '*0111': 24, '*1000': 111, '*1001': 11, '*1010': 74, '*1011': 15, '*1100': 98, '*1101': 29, '*1110': 52, '*1111':  27}

xyz5_abu=plot_histogram([xyz5_abun,xyz5_abux,xyz5_abuy,xyz5_abuz], color=colors1, title='5-Qubit QECC with a nonclassical protection (ancilla) qubits',figsize=(60,20))
yax_abu5 = xyz5_abu.axes[0]
yax_abu5.set_ylim(0,1)
ax_abu5 = xyz5_abu.gca()
xyz5_abu.legend(Legend_Lines1, legend1, bbox_to_anchor=(0.95, 0.95), bbox_transform=ax_abu5.transAxes)
xyz5_abu.savefig('XYZ_5q_arb.png')

# %%
#Comparison of Results of 5 machines
#3Qubit Circuit
#Initial State v00

#X error
xyz3x_sa={'*00': 806, '*01': 52, '*10':  97, '*11': 69}   
xyz3x_vi={'*00': 824, '*01': 53, '*10': 102, '*11': 45}   
xyz3x_va={'*00': 801, '*01': 42, '*10': 145, '*11': 36}   
xyz3x_ou={'*00': 856, '*01': 28, '*10': 105, '*11': 35}   
xyz3x_yt={'*00': 820, '*01': 94, '*10':  60, '*11': 50}   

xyz3x=plot_histogram([xyz3x_sa,xyz3x_vi,xyz3x_va,xyz3x_ou,xyz3x_yt], color=colors2, title='X error',figsize=(20,15))
yax3x = xyz3x.axes[0]
yax3x.set_ylim(0,1)
ax3x = xyz3x.gca()
xyz3x.legend(Legend_Lines2, legend2, bbox_to_anchor=(0.95, 0.95), bbox_transform=ax3x.transAxes)
xyz3x.savefig('XYZ_3q_Xarbcomp.png')

#Y error
xyz3y_sa={'*00': 763, '*01':  45, '*10':  67, '*11': 149}   
xyz3y_vi={'*00': 807, '*01':  62, '*10':  86, '*11':  69}   
xyz3y_va={'*00': 836, '*01':  49, '*10':  88, '*11':  51}   
xyz3y_ou={'*00': 904, '*01':  25, '*10':  78, '*11':  17}   
xyz3y_yt={'*00': 689, '*01': 103, '*10': 135, '*11':  97}   

xyz3y=plot_histogram([xyz3y_sa,xyz3y_vi,xyz3y_va,xyz3y_ou,xyz3y_yt], color=colors2, title='Y error',figsize=(20,15))
yax3y = xyz3y.axes[0]
yax3y.set_ylim(0,1)
ax3y = xyz3y.gca()
xyz3y.legend(Legend_Lines2, legend2, bbox_to_anchor=(0.95, 0.95), bbox_transform=ax3y.transAxes)
xyz3y.savefig('XYZ_3q_Yarbcomp.png')

#Z error
xyz3z_sa={'*00': 843, '*01':  47, '*10':  74, '*11': 60}   
xyz3z_vi={'*00': 854, '*01':  70, '*10':  65, '*11': 35}   
xyz3z_va={'*00': 860, '*01':  50, '*10':  76, '*11': 38}   
xyz3z_ou={'*00': 881, '*01':  31, '*10':  82, '*11': 30}   
xyz3z_yt={'*00': 853, '*01':  78, '*10':  57, '*11': 36}   

xyz3z=plot_histogram([xyz3z_sa,xyz3z_vi,xyz3z_va,xyz3z_ou,xyz3z_yt], color=colors2, title='Z error',figsize=(20,15))
yax3z = xyz3z.axes[0]
yax3z.set_ylim(0,1)
ax3z = xyz3z.gca()
xyz3z.legend(Legend_Lines2, legend2, bbox_to_anchor=(0.95, 0.95), bbox_transform=ax3z.transAxes)
xyz3z.savefig('XYZ_3q_Zarbcomp.png')

# %%
#Comparison of Results of 5 machines
#4Qubit Circuit
#Initial State uv00

#X error
xyz4x_sa={'**00': 916, '**01': 42, '**10':  44, '**11': 22}   
xyz4x_vi={'**00': 826, '**01': 45, '**10': 107, '**11': 46}   
xyz4x_va={'**00': 869, '**01': 70, '**10':  50, '**11': 35}   
xyz4x_ou={'**00': 819, '**01': 51, '**10':  96, '**11': 58}   
xyz4x_yt={'**00': 738, '**01': 91, '**10': 152, '**11': 43}   

xyz4x=plot_histogram([xyz4x_sa,xyz4x_vi,xyz4x_va,xyz4x_ou,xyz4x_yt], color=colors2, title='X error',figsize=(20,15))
yax4x = xyz4x.axes[0]
yax4x.set_ylim(0,1)
ax4x = xyz4x.gca()
xyz4x.legend(Legend_Lines2, legend2, bbox_to_anchor=(0.95, 0.95), bbox_transform=ax4x.transAxes)
xyz4x.savefig('XYZ_4q_Xarbcomp.png')

#Y error
xyz4y_sa={'**00': 923, '**01':  38, '**10':  42, '**11': 21}   
xyz4y_vi={'**00': 807, '**01':  70, '**10':  90, '**11': 57}   
xyz4y_va={'**00': 908, '**01':  33, '**10':  65, '**11': 18}   
xyz4y_ou={'**00': 726, '**01':  73, '**10': 164, '**11': 61}   
xyz4y_yt={'**00': 744, '**01': 108, '**10': 124, '**11': 48}   

xyz4y=plot_histogram([xyz4y_sa,xyz4y_vi,xyz4y_va,xyz4y_ou,xyz4y_yt], color=colors2, title='Y error',figsize=(20,15))
yax4y = xyz4y.axes[0]
yax4y.set_ylim(0,1)
ax4y = xyz4y.gca()
xyz4y.legend(Legend_Lines2, legend2, bbox_to_anchor=(0.95, 0.95), bbox_transform=ax4y.transAxes)
xyz4y.savefig('XYZ_4q_Yarbcomp.png')

#Z error
xyz4z_sa={'**00': 908, '**01':  39, '**10':  63, '**11': 13}   
xyz4z_vi={'**00': 832, '**01':  66, '**10':  92, '**11': 34}   
xyz4z_va={'**00': 868, '**01':  33, '**10': 111, '**11': 12}   
xyz4z_ou={'**00': 807, '**01':  56, '**10': 105, '**11': 56}   
xyz4z_yt={'**00': 781, '**01':  91, '**10': 104, '**11': 48}   

xyz4z=plot_histogram([xyz4z_sa,xyz4z_vi,xyz4z_va,xyz4z_ou,xyz4z_yt], color=colors2, title='Z error',figsize=(20,15))
yax4z = xyz4z.axes[0]
yax4z.set_ylim(0,1)
ax4z = xyz4y.gca()
xyz4z.legend(Legend_Lines2, legend2, bbox_to_anchor=(0.95, 0.95), bbox_transform=ax4z.transAxes)
xyz4z.savefig('XYZ_4q_Zarbcomp.png')

# %%
#Comparison of Results of 5 machines
#5Qubit Circuit
#Initial State u0000

#X error
xyz5x_sa={'*0000': 605, '*0001': 29, '*0010': 26, '*0011': 12, '*0100': 60, '*0101': 23, '*0110': 10, '*0111':  3,'*1000': 171, '*1001': 20, '*1010': 12, '*1011':  1,'*1100': 25, '*1101':  6, '*1110': 17, '*1111':  4}   
xyz5x_vi={'*0000': 567, '*0001': 22, '*0010': 56, '*0011': 15, '*0100': 45, '*0101': 15, '*0110': 13, '*0111':  3,'*1000': 135, '*1001': 14, '*1010': 28, '*1011':  9,'*1100': 43, '*1101': 15, '*1110': 25, '*1111': 19}  
xyz5x_va={'*0000': 535, '*0001': 33, '*0010': 45, '*0011':  8, '*0100': 62, '*0101': 13, '*0110': 19, '*0111':  4,'*1000': 179, '*1001':  8, '*1010': 20, '*1011':  6,'*1100': 37, '*1101': 18, '*1110': 22, '*1111': 15}   
xyz5x_ou={'*0000': 571, '*0001': 30, '*0010': 50, '*0011': 14, '*0100': 40, '*0101': 12, '*0110': 21, '*0111': 13,'*1000': 117, '*1001': 10, '*1010': 13, '*1011':  5,'*1100': 46, '*1101': 18, '*1110': 42, '*1111': 22}    
xyz5x_yt={'*0000': 520, '*0001': 41, '*0010': 67, '*0011': 12, '*0100': 19, '*0101':  5, '*0110':  6, '*0111': 10,'*1000': 165, '*1001': 16, '*1010': 21, '*1011': 10,'*1100': 43, '*1101': 15, '*1110': 35, '*1111': 39}    

xyz5x=plot_histogram([xyz5x_sa,xyz5x_vi,xyz5x_va,xyz5x_ou,xyz5x_yt], color=colors2, title='X error',figsize=(60,20))
yax5x = xyz5x.axes[0]
yax5x.set_ylim(0,1)
ax5x = xyz5x.gca()
xyz5x.legend(Legend_Lines2, legend2, bbox_to_anchor=(0.95, 0.95), bbox_transform=ax5x.transAxes)
xyz5x.savefig('XYZ_5q_Xarbcomp.png')

#Y error
xyz5y_sa={'*0000': 612, '*0001': 26, '*0010': 20, '*0011':  3, '*0100':  37, '*0101':  5, '*0110':  8, '*0111': 9,'*1000': 196, '*1001': 15, '*1010': 12, '*1011':  4,'*1100': 38, '*1101': 11, '*1110': 19, '*1111':  9}   
xyz5y_vi={'*0000': 529, '*0001': 40, '*0010': 82, '*0011': 19, '*0100':  63, '*0101': 15, '*0110':  7, '*0111': 6,'*1000': 108, '*1001':  8, '*1010': 22, '*1011':  9,'*1100': 58, '*1101': 12, '*1110': 36, '*1111': 10}  
xyz5y_va={'*0000': 590, '*0001': 32, '*0010': 21, '*0011':  8, '*0100': 115, '*0101':  5, '*0110': 11, '*0111': 5,'*1000': 120, '*1001':  7, '*1010': 10, '*1011':  7,'*1100': 52, '*1101':  9, '*1110': 22, '*1111': 10}   
xyz5y_ou={'*0000': 510, '*0001': 31, '*0010': 33, '*0011': 14, '*0100':  50, '*0101': 15, '*0110': 14, '*0111': 7,'*1000': 157, '*1001': 14, '*1010': 19, '*1011': 14,'*1100': 46, '*1101': 23, '*1110': 34, '*1111': 43}    
xyz5y_yt={'*0000': 541, '*0001': 38, '*0010': 62, '*0011':  7, '*0100':  19, '*0101':  2, '*0110': 11, '*0111': 3,'*1000': 163, '*1001': 18, '*1010': 22, '*1011': 10,'*1100': 43, '*1101': 25, '*1110': 22, '*1111': 38}    

xyz5y=plot_histogram([xyz5y_sa,xyz5y_vi,xyz5y_va,xyz5y_ou,xyz5y_yt], color=colors2, title='Y error',figsize=(60,20))
yax5y = xyz5y.axes[0]
yax5y.set_ylim(0,1)
ax5y = xyz5y.gca()
xyz5y.legend(Legend_Lines2, legend2, bbox_to_anchor=(0.95, 0.95), bbox_transform=ax5y.transAxes)
xyz5y.savefig('XYZ_5q_Yarbcomp.png')

#Z error
xyz5z_sa={'*0000': 644, '*0001':  9, '*0010': 48, '*0011':  1, '*0100': 73, '*0101': 3, '*0110': 14, '*0111': 0,'*1000': 128, '*1001':  2, '*1010': 22, '*1011':  4, '*1100': 41, '*1101':  3, '*1110': 25, '*1111':  7}   
xyz5z_vi={'*0000': 566, '*0001':  5, '*0010': 88, '*0011':  4, '*0100': 77, '*0101': 2, '*0110': 28, '*0111': 2,'*1000':  79, '*1001':  2, '*1010': 18, '*1011':  3, '*1100': 95, '*1101':  4, '*1110': 49, '*1111':  2}  
xyz5z_va={'*0000': 522, '*0001': 35, '*0010': 55, '*0011': 14, '*0100': 83, '*0101': 9, '*0110': 10, '*0111': 6,'*1000': 180, '*1001': 11, '*1010': 25, '*1011':  5, '*1100': 34, '*1101': 14, '*1110': 12, '*1111':  9}   
xyz5z_ou={'*0000': 566, '*0001': 35, '*0010': 42, '*0011': 17, '*0100': 62, '*0101': 7, '*0110': 12, '*0111': 4,'*1000': 108, '*1001': 18, '*1010': 17, '*1011': 10, '*1100': 52, '*1101': 22, '*1110': 30, '*1111': 22}    
xyz5z_yt={'*0000': 395, '*0001': 28, '*0010': 17, '*0011':  6, '*0100': 44, '*0101': 5, '*0110':  5, '*0111': 6,'*1000': 360, '*1001': 35, '*1010': 14, '*1011':  8, '*1100': 28, '*1101': 13, '*1110': 18, '*1111': 42}    
  

xyz5z=plot_histogram([xyz5z_sa,xyz5z_vi,xyz5z_va,xyz5z_ou,xyz5z_yt], color=colors2, title='Z error',figsize=(60,20))
yax5z = xyz5z.axes[0]
yax5z.set_ylim(0,1)
ax5z = xyz5y.gca()
xyz5z.legend(Legend_Lines2, legend2, bbox_to_anchor=(0.95, 0.95), bbox_transform=ax5z.transAxes)
xyz5z.savefig('XYZ_5q_Zarbcomp.png')
